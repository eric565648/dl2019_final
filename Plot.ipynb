# %%
import pickle

# %%
# reload a file to a variable
with open('./set02_loss_pickle/Train_loss_d.pickle', 'rb') as file:
    Train_loss_d =pickle.load(file)
print(Train_loss_d)

with open('./set02_loss_pickle/Train_loss_phi.pickle', 'rb') as file:
    Train_loss_phi =pickle.load(file)
print(Train_loss_phi)

with open('./set02_loss_pickle/Train_loss.pickle', 'rb') as file:
    Train_loss =pickle.load(file)

print(Train_loss)
# Out:
# [0.486767, 0.493951, 0.477935, 0.492066, 0.494987, 0.493688, 0.49384, 0.493859, 0.499097, 0.504612, 0.492431, 0.488166, 0.492701, 0.489405, 0.494906, 0.493124, 0.493339, 0.493584, 0.493956, 0.493994, 0.494446, 0.494211, 0.494229, 0.494336, 0.494133, 0.494282, 0.494312, 0.49427, 0.494113, 0.493809, 0.494636, 0.49426, 0.494258, 0.494294, 0.494116, 0.494298, 0.494161, 0.494231, 0.494256, 0.494123, 0.494221, 0.494241, 0.494255, 0.494276, 0.494292, 0.494275, 0.494223, 0.494226, 0.494265, 0.49427]
# [0.209281, 0.203565, 0.214954, 0.207803, 0.206175, 0.205545, 0.206348, 0.205273, 0.203059, 0.207242, 0.204706, 0.20386, 0.20941, 0.206097, 0.205685, 0.205252, 0.205309, 0.205314, 0.205737, 0.205956, 0.205676, 0.205872, 0.20585, 0.205878, 0.205603, 0.20565, 0.205628, 0.205758, 0.205774, 0.205914, 0.205689, 0.205718, 0.205812, 0.205683, 0.205738, 0.20578, 0.205774, 0.205712, 0.205687, 0.205707, 0.205739, 0.205676, 0.205674, 0.205707, 0.205733, 0.205718, 0.205677, 0.205663, 0.205715, 0.205711]
# ...

# %%
with open('./set02_loss_pickle/Test_loss_d.pickle', 'rb') as file:
    Test_loss_d =pickle.load(file)
print(Test_loss_d)

with open('./set02_loss_pickle/Test_loss_phi.pickle', 'rb') as file:
    Test_loss_phi =pickle.load(file)
print(Test_loss_phi)
# Out:
# [0.092491, 0.088769, 0.095575, 0.088709, 0.0915, 0.089287, 0.089355, 0.088444, 0.088848, 0.086812, 0.089867, 0.091243, 0.088939, 0.088528, 0.089202, 0.089168, 0.089064, 0.089074, 0.088843, 0.08895, 0.088901, 0.088791, 0.089072, 0.088781, 0.089005, 0.088962, 0.089001, 0.088841, 0.088862, 0.089034, 0.088876, 0.088867, 0.088901, 0.08892, 0.088878, 0.088854, 0.088918, 0.088822, 0.088925, 0.088876, 0.088874, 0.088904, 0.088887, 0.088854, 0.088877, 0.088881, 0.088889, 0.08887, 0.08889, 0.088882]
# [0.01285, 0.01263, 0.0123, 0.012189, 0.012627, 0.012535, 0.012974, 0.012677, 0.012606, 0.013002, 0.012574, 0.012615, 0.012649, 0.012579, 0.012725, 0.012729, 0.012696, 0.012694, 0.012838, 0.012652, 0.012626, 0.012724, 0.012687, 0.012704, 0.012705, 0.012679, 0.012691, 0.012753, 0.012674, 0.012742, 0.012733, 0.012709, 0.01271, 0.012688, 0.012699, 0.012699, 0.012708, 0.012712, 0.012696, 0.012698, 0.012719, 0.012713, 0.012694, 0.012709, 0.012701, 0.012709, 0.012704, 0.012701, 0.012703, 0.012704]
